# %% [markdown]
# # Proyecto Final Tratamiento de Datos
#
# Carlos Guerrero Valarezo
#
# Maestria Ciberseguridad

# %%
#Versiones que tenemos instaladas en el sistema
# scipy
import scipy
print('scipy: %s' % scipy.__version__)
# numpy
import numpy
print('numpy: %s' % numpy.__version__)
# matplotlib
import matplotlib
print('matplotlib: %s' % matplotlib.__version__)
# pandas
import pandas
print('pandas: %s' % pandas.__version__)
# statsmodels
import statsmodels
print('statsmodels: %s' % statsmodels.__version__)
# scikit-learn
import sklearn
print('sklearn: %s' % sklearn.__version__)
# tensorflow
import tensorflow
print('tensorflow: %s' % tensorflow.__version__)
# keras
import keras
print('keras: %s' % keras.__version__)
# cv2
import cv2
print('cv2: %s' % cv2.__version__)
# re
import re
print('re: %s' % re.__version__)
# Out:
# scipy: 1.7.3
# numpy: 1.21.5
# matplotlib: 3.5.3
# pandas: 1.3.5
# statsmodels: 0.13.2
# sklearn: 1.0.2
# tensorflow: 2.8.2
# keras: 2.8.0
# cv2: 4.6.0
# re: 2.2.1

# %%
#Importacion de Librerias 
import numpy as np
import os
import re
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import  Sequential,Input,Model
from tensorflow.python.keras import optimizers

#import
from keras.datasets import mnist
from tensorflow.keras.layers import Dense, Dropout, Flatten #Para la red neuronal
from tensorflow.keras.layers import Conv2D, MaxPooling2D #para implementar las capas convolucionales
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import LeakyReLU

# %%
#Cargar, Contar y Leer fotos de directorio
dirname = os.path.join(os.getcwd(), '../../../CarneDataset/train') #Path directorio de Fotos
imgpath = dirname + os.sep 

images = []
directories = []
dircount = []
prevRoot=''
cant=0
longitud, altura = 200, 200
tamano_pool = (2, 2)
print("Leyendo imagenes de ",imgpath)

for root, dirnames, filenames in os.walk(imgpath):
    for filename in filenames:
        if re.search("\.(jpg|jpeg|png|bmp|tiff)$", filename):
            cant=cant+1
            filepath = os.path.join(root, filename)
            image = plt.imread(filepath) #cargará a memoria un arreglo de imágenes.
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) #Convertir a escala de grises
            image = cv2.GaussianBlur(image, (3, 3), 0)   #Aplicar filtro gaussiano
            image = cv2.blur(image, (3, 3))   #Aplicar filtro difuminado
            image = cv2.medianBlur(image,5)
            image = cv2.resize(image,(longitud,altura))
            #image = filters.sobel(image)          
            images.append(image)
            b = "Leyendo..." + str(cant)
            print (b, end="\r")
            if prevRoot !=root:
                print(root, cant)
                prevRoot=root
                directories.append(root)
                dircount.append(cant)
                cant=0
dircount.append(cant)

dircount = dircount[1:]
dircount[0]=dircount[0]+1
print('Directorios leidos:',len(directories))
print("Imagenes en cada directorio", dircount)
print('suma Total de imagenes en subdirectorios:',sum(dircount))
# Out:
# Leyendo imagenes de  C:\Users\MGZ\Documents\GitHub\projectcgv\../../../CarneDataset/train\
# C:\Users\MGZ\Documents\GitHub\projectcgv\../../../CarneDataset/train\CLASS_02 1
# C:\Users\MGZ\Documents\GitHub\projectcgv\../../../CarneDataset/train\CLASS_03 62
# C:\Users\MGZ\Documents\GitHub\projectcgv\../../../CarneDataset/train\CLASS_04 213
# C:\Users\MGZ\Documents\GitHub\projectcgv\../../../CarneDataset/train\CLASS_05 105
# C:\Users\MGZ\Documents\GitHub\projectcgv\../../../CarneDataset/train\CLASS_06 949
# C:\Users\MGZ\Documents\GitHub\projectcgv\../../../CarneDataset/train\CLASS_07 37
# C:\Users\MGZ\Documents\GitHub\projectcgv\../../../CarneDataset/train\CLASS_08 204
# Directorios leidos: 7
# Imagenes en cada directorio [63, 213, 105, 949, 37, 204, 62]
# suma Total de imagenes en subdirectorios: 1633

# %%
#Creación de etiquetas
labels=[]
indice=0
for cantidad in dircount:
    for i in range(cantidad):
        labels.append(indice)
    indice=indice+1
print("Cantidad etiquetas creadas: ",len(labels))

carnes_clases=[]
indice=0
for directorio in directories:
    name = directorio.split(os.sep)
    print(indice , name[len(name)-1])
    carnes_clases.append(name[len(name)-1])
    indice=indice+1

y = np.array(labels)
X = np.array(images, dtype=np.uint8) #convierto de lista a numpy


classes = np.unique(y)
nClasses = len(classes)
print('Cantidad Total de Clases : ', nClasses)
print('Arreglo de clases creadas : ', classes)
# Out:
# Cantidad etiquetas creadas:  1633
# 0 CLASS_02
# 1 CLASS_03
# 2 CLASS_04
# 3 CLASS_05
# 4 CLASS_06
# 5 CLASS_07
# 6 CLASS_08
# Cantidad Total de Clases :  7
# Arreglo de clases creadas :  [0 1 2 3 4 5 6]

# %%
#Mezclar todo y crear los grupos de entrenamiento y testing
train_X,test_X,train_Y,test_Y = train_test_split(X,y,test_size=0.2) #subdividimos los datos en 80/20 test y entrenamiento
print('Entrenamiento Data Shape : ', train_X.shape, train_Y.shape)
print('Pruebas Data Shape : ', test_X.shape, test_Y.shape)

train_X = train_X.astype('float32')
test_X = test_X.astype('float32')
train_X = train_X / 255. #Preprocesamos el valor de los pixeles y lo normalizamos para que tengan un valor entre 0 y 1
test_X = test_X / 255.  #Preprocesamos el valor de los pixeles y lo normalizamos para que tengan un valor entre 0 y 1

# CAmbiar etiquetas de categorical a one-hot encoding
train_Y_one_hot = to_categorical(train_Y)
test_Y_one_hot = to_categorical(test_Y)

# Mostrar cambio de categoria etiqueta usando one-hot encoding
print('Etiqueta Original:', train_Y[0])
print('Despues de la conversion one-hot:', train_Y_one_hot[0])


train_X,valid_X,train_label,valid_label = train_test_split(train_X, train_Y_one_hot, test_size=0.2, random_state=13)

print(train_X.shape,valid_X.shape,train_label.shape,valid_label.shape)
# Out:
# Entrenamiento Data Shape :  (1306, 200, 200, 3) (1306,)
# Pruebas Data Shape :  (327, 200, 200, 3) (327,)
# Etiqueta Original: 2
# Despues de la conversion one-hot: [0. 0. 1. 0. 0. 0. 0.]
# (1044, 200, 200, 3) (262, 200, 200, 3) (1044, 7) (262, 7)

# %%
#Creacion de la Red Convolucional
INIT_LR = 1e-3
epochs = 20
batch_size = 64
filtros_convo=32
filtros_convo2=64
tamano_filtro=(3, 3)
tamano_filtro2=(2, 2)

carnes_model = Sequential() #crear contenedor del modelo, en donde progresivamente se irán añadiendo las capas de la Red Convolucional
carnes_model.add(Conv2D(filtros_convo, tamano_filtro,tamano_filtro,padding ="same", input_shape=(longitud, altura, 3), activation='linear'))
carnes_model.add(LeakyReLU(alpha=0.1))
carnes_model.add(MaxPooling2D(pool_size=tamano_pool))
carnes_model.add(Conv2D(filtros_convo2, tamano_filtro2, padding ="same"))
carnes_model.add(MaxPooling2D(pool_size=tamano_pool))
carnes_model.add(Flatten())
carnes_model.add(Dense(256, activation='linear'))
carnes_model.add(Dropout(0.5))
carnes_model.add(Dense(nClasses, activation='softmax'))
carnes_model.summary()
#sgd = SGD(learning_rate=0.1)
#carnes_model.compile(loss=tensorflow.keras.losses.categorical_crossentropy,optimizer=tensorflow.keras.optimizers.Adagrad(learning_rate=INIT_LR, decay=INIT_LR / 100),metrics=['accuracy'])
carnes_model.compile (loss='categorical_crossentropy',optimizer=tensorflow.keras.optimizers.Adagrad(learning_rate=INIT_LR, decay=INIT_LR / 100) ,metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 67, 67, 32)        896
#
#  leaky_re_lu (LeakyReLU)     (None, 67, 67, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 33, 33, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 33, 33, 64)        8256
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 256)               4194560
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 4,205,511
# Trainable params: 4,205,511
# Non-trainable params: 0
# _________________________________________________________________

# %%
carnes_train_dropout = carnes_model.fit(train_X, train_label, batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(valid_X, valid_label))
# Guardamos la informacion para no volver a generar en el futuro
carnes_model.save('./modelo/modelo.h5')
carnes_model.save_weights('./modelo/pesos.h5')
# Out:
# Epoch 1/50
# 17/17 [==============================] - 4s 179ms/step - loss: 1.9151 - accuracy: 0.5565 - val_loss: 1.8852 - val_accuracy: 0.5725
# Epoch 2/50
# 17/17 [==============================] - 3s 165ms/step - loss: 1.8546 - accuracy: 0.5862 - val_loss: 1.8243 - val_accuracy: 0.5725
# Epoch 3/50
# 17/17 [==============================] - 3s 171ms/step - loss: 1.7844 - accuracy: 0.5862 - val_loss: 1.7496 - val_accuracy: 0.5725
# Epoch 4/50
# 17/17 [==============================] - 3s 164ms/step - loss: 1.6968 - accuracy: 0.5862 - val_loss: 1.6574 - val_accuracy: 0.5725
# Epoch 5/50
# 17/17 [==============================] - 3s 151ms/step - loss: 1.5980 - accuracy: 0.5862 - val_loss: 1.5604 - val_accuracy: 0.5725
# Epoch 6/50
# 17/17 [==============================] - 3s 155ms/step - loss: 1.5048 - accuracy: 0.5862 - val_loss: 1.4855 - val_accuracy: 0.5725
# Epoch 7/50
# 17/17 [==============================] - 3s 151ms/step - loss: 1.4304 - accuracy: 0.5862 - val_loss: 1.4407 - val_accuracy: 0.5725
# Epoch 8/50
# 17/17 [==============================] - 3s 173ms/step - loss: 1.3942 - accuracy: 0.5862 - val_loss: 1.4192 - val_accuracy: 0.5725
# Epoch 9/50
# 17/17 [==============================] - 3s 168ms/step - loss: 1.3834 - accuracy: 0.5862 - val_loss: 1.4106 - val_accuracy: 0.5725
# Epoch 10/50
# 17/17 [==============================] - 3s 164ms/step - loss: 1.3680 - accuracy: 0.5862 - val_loss: 1.4067 - val_accuracy: 0.5725
# Epoch 11/50
# 17/17 [==============================] - 3s 154ms/step - loss: 1.3647 - accuracy: 0.5862 - val_loss: 1.4051 - val_accuracy: 0.5725
# Epoch 12/50
# 17/17 [==============================] - 3s 152ms/step - loss: 1.3566 - accuracy: 0.5862 - val_loss: 1.4045 - val_accuracy: 0.5725
# Epoch 13/50
# 17/17 [==============================] - 3s 149ms/step - loss: 1.3583 - accuracy: 0.5862 - val_loss: 1.4042 - val_accuracy: 0.5725
# Epoch 14/50
# 17/17 [==============================] - 3s 164ms/step - loss: 1.3526 - accuracy: 0.5862 - val_loss: 1.4044 - val_accuracy: 0.5725
# Epoch 15/50
# 17/17 [==============================] - 3s 175ms/step - loss: 1.3494 - accuracy: 0.5862 - val_loss: 1.4040 - val_accuracy: 0.5725
# Epoch 16/50
# 17/17 [==============================] - 3s 171ms/step - loss: 1.3524 - accuracy: 0.5862 - val_loss: 1.4041 - val_accuracy: 0.5725
# Epoch 17/50
# 17/17 [==============================] - 3s 168ms/step - loss: 1.3603 - accuracy: 0.5862 - val_loss: 1.4044 - val_accuracy: 0.5725
# Epoch 18/50
# 17/17 [==============================] - 3s 161ms/step - loss: 1.3561 - accuracy: 0.5862 - val_loss: 1.4046 - val_accuracy: 0.5725
# Epoch 19/50
# 17/17 [==============================] - 3s 167ms/step - loss: 1.3421 - accuracy: 0.5862 - val_loss: 1.4049 - val_accuracy: 0.5725
# Epoch 20/50
# 17/17 [==============================] - 3s 175ms/step - loss: 1.3518 - accuracy: 0.5862 - val_loss: 1.4054 - val_accuracy: 0.5725
# Epoch 21/50
# 17/17 [==============================] - 3s 182ms/step - loss: 1.3435 - accuracy: 0.5862 - val_loss: 1.4054 - val_accuracy: 0.5725
# Epoch 22/50
# 17/17 [==============================] - 3s 165ms/step - loss: 1.3520 - accuracy: 0.5862 - val_loss: 1.4057 - val_accuracy: 0.5725
# Epoch 23/50
# 17/17 [==============================] - 2s 146ms/step - loss: 1.3471 - accuracy: 0.5862 - val_loss: 1.4061 - val_accuracy: 0.5725
# Epoch 24/50
# 17/17 [==============================] - 3s 149ms/step - loss: 1.3521 - accuracy: 0.5862 - val_loss: 1.4060 - val_accuracy: 0.5725
# Epoch 25/50
# 17/17 [==============================] - 3s 164ms/step - loss: 1.3422 - accuracy: 0.5862 - val_loss: 1.4061 - val_accuracy: 0.5725
# Epoch 26/50
# 17/17 [==============================] - 3s 172ms/step - loss: 1.3452 - accuracy: 0.5862 - val_loss: 1.4062 - val_accuracy: 0.5725
# Epoch 27/50
# 17/17 [==============================] - 3s 165ms/step - loss: 1.3438 - accuracy: 0.5862 - val_loss: 1.4064 - val_accuracy: 0.5725
# Epoch 28/50
# 17/17 [==============================] - 3s 150ms/step - loss: 1.3411 - accuracy: 0.5862 - val_loss: 1.4066 - val_accuracy: 0.5725
# Epoch 29/50
# 17/17 [==============================] - 3s 151ms/step - loss: 1.3482 - accuracy: 0.5862 - val_loss: 1.4068 - val_accuracy: 0.5725
# Epoch 30/50
# 17/17 [==============================] - 3s 154ms/step - loss: 1.3419 - accuracy: 0.5862 - val_loss: 1.4070 - val_accuracy: 0.5725
# Epoch 31/50
# 17/17 [==============================] - 3s 166ms/step - loss: 1.3472 - accuracy: 0.5862 - val_loss: 1.4078 - val_accuracy: 0.5725
# Epoch 32/50
# 17/17 [==============================] - 3s 172ms/step - loss: 1.3485 - accuracy: 0.5862 - val_loss: 1.4074 - val_accuracy: 0.5725
# Epoch 33/50
# 17/17 [==============================] - 3s 168ms/step - loss: 1.3425 - accuracy: 0.5862 - val_loss: 1.4074 - val_accuracy: 0.5725
# Epoch 34/50
# 17/17 [==============================] - 3s 154ms/step - loss: 1.3449 - accuracy: 0.5862 - val_loss: 1.4080 - val_accuracy: 0.5725
# Epoch 35/50
# 17/17 [==============================] - 3s 154ms/step - loss: 1.3499 - accuracy: 0.5862 - val_loss: 1.4082 - val_accuracy: 0.5725
# Epoch 36/50
# 17/17 [==============================] - 3s 150ms/step - loss: 1.3406 - accuracy: 0.5862 - val_loss: 1.4084 - val_accuracy: 0.5725
# Epoch 37/50
# 17/17 [==============================] - 3s 170ms/step - loss: 1.3437 - accuracy: 0.5862 - val_loss: 1.4084 - val_accuracy: 0.5725
# Epoch 38/50
# 17/17 [==============================] - 3s 177ms/step - loss: 1.3449 - accuracy: 0.5862 - val_loss: 1.4081 - val_accuracy: 0.5725
# Epoch 39/50
# 17/17 [==============================] - 3s 166ms/step - loss: 1.3438 - accuracy: 0.5862 - val_loss: 1.4083 - val_accuracy: 0.5725
# Epoch 40/50
# 17/17 [==============================] - 3s 152ms/step - loss: 1.3410 - accuracy: 0.5862 - val_loss: 1.4081 - val_accuracy: 0.5725
# Epoch 41/50
# 17/17 [==============================] - 3s 157ms/step - loss: 1.3467 - accuracy: 0.5862 - val_loss: 1.4077 - val_accuracy: 0.5725
# Epoch 42/50
# 17/17 [==============================] - 3s 156ms/step - loss: 1.3487 - accuracy: 0.5862 - val_loss: 1.4075 - val_accuracy: 0.5725
# Epoch 43/50
# 17/17 [==============================] - 3s 191ms/step - loss: 1.3472 - accuracy: 0.5862 - val_loss: 1.4078 - val_accuracy: 0.5725
# Epoch 44/50
# 17/17 [==============================] - 3s 185ms/step - loss: 1.3337 - accuracy: 0.5862 - val_loss: 1.4076 - val_accuracy: 0.5725
# Epoch 45/50
# 17/17 [==============================] - 3s 169ms/step - loss: 1.3448 - accuracy: 0.5862 - val_loss: 1.4082 - val_accuracy: 0.5725
# Epoch 46/50
# 17/17 [==============================] - 3s 164ms/step - loss: 1.3463 - accuracy: 0.5862 - val_loss: 1.4082 - val_accuracy: 0.5725
# Epoch 47/50
# 17/17 [==============================] - 3s 166ms/step - loss: 1.3483 - accuracy: 0.5862 - val_loss: 1.4081 - val_accuracy: 0.5725
# Epoch 48/50
# 17/17 [==============================] - 3s 181ms/step - loss: 1.3419 - accuracy: 0.5862 - val_loss: 1.4075 - val_accuracy: 0.5725
# Epoch 49/50
# 17/17 [==============================] - 3s 183ms/step - loss: 1.3447 - accuracy: 0.5862 - val_loss: 1.4072 - val_accuracy: 0.5725
# Epoch 50/50
# 17/17 [==============================] - 3s 167ms/step - loss: 1.3510 - accuracy: 0.5862 - val_loss: 1.4069 - val_accuracy: 0.5725

# %%
test_eval = carnes_model.evaluate(test_X, test_Y_one_hot, verbose=1)

 

print('Test Red CNN:')

print('Perdida:', test_eval[0])

print('Exactitud:', test_eval[1])

 

accuracy = carnes_train_dropout.history['accuracy']

val_accuracy = carnes_train_dropout.history['val_accuracy']

loss = carnes_train_dropout.history['loss']

val_loss = carnes_train_dropout.history['val_loss']

epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'bo', label='Precision de entrenamiento')

plt.plot(epochs, val_accuracy, 'b', label='Exactitud de la validacion')

plt.title('Precisión de entrenamiento y validación')

plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Perdida de entrenamiento')

plt.plot(epochs, val_loss, 'b', label='Perdida de validacion')

plt.title('Perdida de entrenamiento y validacion')

plt.legend()

plt.show()
# Out:
# 11/11 [==============================] - 0s 21ms/step - loss: 1.3668 - accuracy: 0.5719
# Test Red CNN:
# Perdida: 1.3667880296707153
# Exactitud: 0.571865439414978

# %%
import numpy as np
from keras.preprocessing.image import load_img, img_to_array
from keras.models import load_model

longitud, altura = 200, 200
modelo = './modelo/modelo.h5'
pesos_modelo = './modelo/pesos.h5'
cnn = load_model(modelo)
cnn.load_weights(pesos_modelo)

def predict(file):
  x = load_img(file, target_size=(longitud, altura))
  x = img_to_array(x)
  x = np.expand_dims(x, axis=0)
  array = cnn.predict(x)
  result = array[0]
  answer = np.argmax(result)
  if answer == 0:
    print("Pertenece a CLASS_02")
  elif answer == 1:
    print("Pertenece a CLASS_03")
  elif answer == 2:
    print("Pertenece a CLASS_04")
  elif answer == 3:
    print("Pertenece a CLASS_05")
  elif answer == 4:
    print("Pertenece a CLASS_06")
  elif answer == 5:
    print("Pertenece a CLASS_07")
  elif answer == 6:
    print("Pertenece a CLASS_08")
  else :
    print("Pertenece a CLASS_01")
  return answer

predict ("14-CAPTURE_20220523_141530_080.png")
predict ("1.png")
# Out:
# Pertenece a CLASS_05
# Pertenece a CLASS_05
# 3
