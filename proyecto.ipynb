# %% [markdown]
# # Proyecto Final

# %% [markdown]
# Materia: Tratamientos de Datos
#
# Maestria CiberSeguridad
#
# Carlos Guerrero Valarezo

# %%
# importamos el modulo pyplot, y lo llamamos plt
import matplotlib.pyplot as plt

#configuracion necesaria de pyplot para ver las imagenes en escala de grises
plt.rcParams['image.cmap'] = 'gray'


# comando de Jupyter para que las imagenes se muestren automaticamente 
# %matplotlib inline

#tambien importamos numpy ya que lo usamos para crear y manipular matrices

from PIL import Image,ImageOps
import pandas as pd
import numpy as np
import cv2
img=cv2.imread("leon.png")
hsv= cv2.cvtColor(img, cv2.COLOR_BGR2HSV )
gray= cv2.cvtColor(img, cv2.COLOR_BGR2GRAY )
cv2.imshow("CG", img)
cv2.imshow("CG1", hsv)
cv2.imshow("CG2", gray)

#color_imagen = Image.open("leon.png")
#color_pixel = colourImg.convert("RGB")
#color_arreglo = np.array(color_pixel.getdata())
print("------------------------------------------------ARREGLO")
arreglo2=np.array(Image.open("leonbn.png"))

#df = pd.DataFrame(color_arreglo, columns=["red","green","blue"])
# Out:
# ------------------------------------------------ARREGLO

# %%
import cv2
print('cv2: %s' % cv2.__version__)
# Out:
# cv2: 4.6.0

# %%
print(color_imagen.format)

print(color_imagen.size)

print(color_imagen.mode)

# show the image

color_imagen.show()

# %%
from PIL import Image,ImageOps
from matplotlib import image

from matplotlib import pyplot

# load image as pixel array

image =(image.imread('leonbn.png'))



# summarize shape of the pixel array

print(image.dtype)

print(image.shape)

# display the array of pixels as an image

pyplot.imshow(image)

pyplot.show()
# Out:
# float32
# (1470, 1960)

# %%
from matplotlib import pyplot
img =Image.open("leon.png")

img=img.convert("L")
img.show(img)
img.save("leonbn.png")

# %%
import numpy as np
from PIL import Image

img = Image.open('telco.png').convert('RGBA')
arr = np.array(img)

# record the original shape
shape = arr.shape
print (shape)

# make a 1-dimensional view of arr
flat_arr = arr.ravel()
print (flat_arr)
print("array")
# convert it to a matrix
vector = np.matrix(flat_arr)
print (vector)
# do something to the vector
vector[:,::10] = 128
print("---------------------")
print (vector)
# reform a numpy array of the original shape
arr2 = np.asarray(vector).reshape(shape)

# make a PIL image
img2 = Image.fromarray(arr2, 'RGBA')
#img2.show()

# %%
# scipy
import scipy
print('scipy: %s' % scipy.__version__)
# numpy
import numpy
print('numpy: %s' % numpy.__version__)
# matplotlib
import matplotlib
print('matplotlib: %s' % matplotlib.__version__)
# pandas
import pandas
print('pandas: %s' % pandas.__version__)
# statsmodels
import statsmodels
print('statsmodels: %s' % statsmodels.__version__)
# scikit-learn
import sklearn
print('sklearn: %s' % sklearn.__version__)

# tensorflow
import tensorflow
print('tensorflow: %s' % tensorflow.__version__)
# keras
import keras
print('keras: %s' % keras.__version__)
